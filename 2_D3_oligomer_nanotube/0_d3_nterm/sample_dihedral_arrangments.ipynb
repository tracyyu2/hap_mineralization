# %%
import numpy as np
translations = np.arange(53, 56, 0.5)
# translations = np.arange(-1, 2, 0.5)
rotations = np.arange(30, 120, 60)

# %%
len(translations) * len(rotations)
# Out:
# 12

# %%
commands = []

chainA_length = 265

for rot in rotations:
    for trans in translations:
        commands.append(f'''/software/rosetta/latest/bin/rosetta_scripts.hdf5.linuxgccrelease \
-database /software/rosetta/latest/database @rosetta_scripts.flag \
-s /home/tracyy2/fiber_design/Dihedral/00_dihedral_rosetta/input/d5_D9_chainA_Ala.pdb \
-scorefile score.sc  \
-parser:script_vars translate_X=0 translate_Y=0 translate_Z=1 distance={trans} sym=D3_Z.sym angle={rot} nres={chainA_length*3} \
-out:suffix _trans{trans}_rot{rot} \
-parser:protocol dihedral_symmetrize_and_translate_and_spin.xml -mute all''')

# %%
with open('task.list', 'w') as command_file:
    for cmd in commands:
        print (cmd, file=command_file)

# %%
# commands[0]
